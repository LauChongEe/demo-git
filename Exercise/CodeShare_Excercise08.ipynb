# %%
## Exercise 08

##KH

## Question 1
def answer_one():
    df = pd.merge(ScimEn1, energy, how='inner',left_on='Country', right_on='Country')
    new_df = pd.merge(df,GDP,how='inner',left_on='Country',right_on='Country')
    new_df = new_df.set_index('Country')
    return new_df
   
answer_one()

## Question 2
def answer_two():
    df = pd.merge(ScimEn,energy,how='inner',left_on='Country',right_on='Country')
    new_df1 = pd.merge(df,GDP,how='inner',left_on='Country',right_on='Country')
    new_df1 = new_df1.set_index('Country')
    print(new_df1.shape)

answer_two()

## Question 3
def answer_three():
    Top15 = answer_one()
    avgGDP = Top15[['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015']].mean(axis=1)
    avgGDP.sort_values(ascending=False, inplace=True)
    return avgGDP

answer_three()

## Question 4
def answer_four():
    Top15=answer_one()
    sixth = abs(Top15.iloc[3,10]-Top15.iloc[3,19])
    return sixth

answer_four()

## Question 5
def answer_five():
    Top15 = answer_one()
    ESPC = Top15['Energy Supply per Capita'].mean()
    return ESPC

answer_five()

## Question 6
def answer_six():
    Top15 = answer_one()
    Renewable= Top15["% Renewable"].max()
    country = Top15['% Renewable'].argmax()
    return (country,Renewable)
       
answer_six()

## Question 7
def answer_seven():
    Top15 = answer_one()
    Top15['Ratio'] = Top15['Self-citations']/Top15['Citations']
    MaxRatio= Top15['Ratio'].max()
    country = Top15['Ratio'].argmax()
    return (country, MaxRatio)

answer_seven()

## Question 8
def answer_eight():
    Top15 = answer_one()
    Top15['Pop'] = Top15['Energy Supply']/Top15['Energy Supply per Capita']
    SortedPop = Top15['Pop'].sort_values(ascending = False)
    return SortedPop.index[2]

answer_eight()

## Question 9
def answer_nine():
    Top15 = answer_one()
    Top15['Pop'] = Top15['Energy Supply']/Top15['Energy Supply per Capita']
    Top15['CitePerPerson']=Top15['Citable documents']/Top15['Pop']
    correlation = Top15[['Energy Supply per Capita','CitePerPerson']].corr(method='pearson').values[0,1]
    return correlation

answer_nine()

## Question 10
def answer_ten():
    Top15 = answer_one()
    renewable_median = answer_one()['% Renewable'].median()
    Top15['HighRenew'] = Top15['% Renewable'].apply(lambda x: 1 if x > renewable_median else 0)
    return Top15['HighRenew']
 
answer_ten()

## Question 11
def answer_eleven():
    Top15 = answer_one()
    ContinentDict  = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}
    Top15['size'] = None
    Top15['Pop'] = Top15['Energy Supply']/Top15['Energy Supply per Capita']
    Top15['Continent'] = None
    for i in range(len(Top15)):
        Top15.iloc[i,20] = 1
        Top15.iloc[i,22]= ContinentDict[Top15.index[i]]
    = Top15.set_index('Continent').groupby(level=0)['Pop'].agg({'size': np.size, 'sum': np.sum, 'mean': np.mean,'std': np.std})
    ans = ans[['size', 'sum', 'mean', 'std']]
    return ans
    return "ANSWER"

## Question 12
def answer_twelve():
    Top15 = answer_one()
    Top15['PopEst'] = Top15['Energy Supply'] / Top15['Energy Supply per Capita']
    return Top15['PopEst'].map(lambda x: "{:,}".format(x))

answer_twelve()


#########################################
# Yu

# Question 1



# ScimEn1 = ScimEn1.set_index('Country')
# GDP = GDP.set_index('Country')
# energy = energy.set_index('Country')
def answer_one(DF1, DF2, DF3):
    a =pd.merge(DF1, DF2, how='inner', left_index=True, right_index=True)
    df_merged_all=pd.merge(a, DF3, how='inner', left_index=True, right_index=True)
    
    return df_merged_all

answer_one(ScimEn1, energy, GDP)
    
    

# Question2


# ScimEn = ScimEn.set_index('Country')
def answer_two(DF1, DF2, DF3):
    a = answer_one (DF1, DF2, DF3)
    return len(a) - 15

answer_two(ScimEn, GDP, energy)

    
    

# Question3

def answer_three(DF1, DF2, DF3):


    answer_one_countries = answer_one(DF1, DF2, DF3)

    return(answer_one_countries
        .loc[:,"2006":"2015"]
        .mean(axis=1)
        .sort_values(ascending=False))

answer_three(ScimEn1, energy, GDP)




# Question4

DF4 = answer_one(ScimEn1, energy, GDP)
DF4['avgGDP'] = answer_three(ScimEn1, energy, GDP)
DF4 = DF4.sort_values('avgGDP' ,ascending=False)

def answer_four(df):
    df = df['2015'].subtract(df['2006']).iloc[5]
    return df

answer_four(DF4)



# Question5


def answer_five(df):
    df5 = df['Energy Supply per Capita']
    return df5.mean()

answer_five(DF4)


# Question6


def answer_six(df):

    df6 = df.sort_values('% Renewable' ,ascending=False)
    max_index = df6['% Renewable'].argmax()
    max_value = df6['% Renewable'].max()
    return (max_index,max_value)

answer_six(DF4)


# Question 7

def answer_seven(df):
    df7 = df
    df7['ratio'] = df['Self-citations']/df['Citations']
    max_index = df7['ratio'].argmax()
    max_value = df7['ratio'].max()
    return (max_index,max_value)

answer_seven(DF4)




#########################################

# Ariff

# Question 1

def answer_one():
    df_temp = pd.merge(ScimEn1.set_index('Country'), energy.set_index('Country'), how='inner', left_index=True, right_index=True)
    return pd.merge(df_temp, GDP.set_index('Country'), how='inner', left_index=True, right_index=True)
answer_one()

# Question 2

def answer_two():
    df_temp = pd.merge(ScimEn.set_index('Country'), energy.set_index('Country'), how='inner',
                       left_index=True, right_index=True)
    df_temp = pd.merge(df_temp, GDP.set_index('Country'), how='inner', left_index=True, right_index=True)
    return (df_temp.shape)[0] - (answer_one().shape)[0]

answer_two()

# Question 3

def answer_three():
    ## Your answer here
    df_temp = answer_one()
    last_10_years = GDP.set_index('Country').columns
    df_temp['temp'] = df_temp[last_10_years].mean(axis=1)
    df_temp = df_temp.sort_values(by=['temp'],ascending=False)
    return df_temp['temp']
answer_three()

# Question 4

def answer_four():
    df_temp = answer_one()
    df_temp['mean'] = answer_three()
    df_temp = df_temp.sort_values('mean', ascending=False)
    ten_years_span = ['2015','2006']
    return df_temp['2015'].subtract(df_temp['2006']).iloc[5]
    
answer_four()

## Question 5
def answer_five():
    Top15 = answer_one()
    ESPC = Top15['Energy Supply per Capita'].mean()
    return ESPC

answer_five()

# Question 5

def answer_five():
    df_temp = answer_one()
    return "{0:.1f}".format(df_temp['Energy Supply per Capita'].mean())

answer_five()

# Question 6

def answer_six():
    df_temp = answer_one()
    max_country= df_temp['% Renewable'].idxmax()
    max_val = df_temp.get_value(max_country, '% Renewable')
    return (max_country, max_val)


answer_six()

# Question 7
def answer_seven():
    df_temp = answer_one()
    df_temp['Ratio'] = df_temp['Self-citations'] / df_temp['Citations']

    return (df_temp['Ratio'].idxmax(), df_temp['Ratio'].max())

answer_seven()

# Question 8

def answer_eight():
    df_temp = answer_one()
    df_temp['Population'] = df_temp['Energy Supply'] / df_temp['Energy Supply per Capita']
    df_temp = df_temp.sort_values('Population',ascending=False)
    return (df_temp.iloc[[2]].index)[0]

answer_eight()

# Question 9
def answer_nine():
    ## Your answer here
    df_temp = population()
    df_temp['Citable_Documents_Per_Capita'] = df_temp['Citable documents'] / df_temp['Population']
    return df_temp['Citable_Documents_Per_Capita'].corr(df_temp['Energy Supply per Capita'],method='pearson')

answer_nine()

# Question 10
def answer_ten():
    df_temp = population()
    mask = df_temp['% Renewable'] >= df_temp['% Renewable'].median()
    df_temp.loc[mask, 'Renewable_Above_Median'] = 1
    df_temp.loc[~mask, 'Renewable_Above_Median'] = 0
    return df_temp['Renewable_Above_Median'].astype(int)
answer_ten()


# Question 11
def answer_eleven():
## Your answer here
    df_temp = population()
    df_temp['Continent'] = pd.Series({'China':'Asia', 
                      'United States':'North America', 
                      'Japan':'Asia', 
                      'United Kingdom':'Europe', 
                      'Russian Federation':'Europe', 
                      'Canada':'North America', 
                      'Germany':'Europe', 
                      'India':'Asia',
                      'France':'Europe', 
                      'South Korea':'Asia', 
                      'Italy':'Europe', 
                      'Spain':'Europe', 
                      'Iran':'Asia',
                      'Australia':'Australia', 
                      'Brazil':'South America'})

    return pd.pivot_table(df_temp, index=['Continent'], values='Population', aggfunc=('size','sum','mean','std'))

answer_eleven()

# Question 12

def answer_twelve():
    df = population()
    thousands_separator = lambda x : "{:,}".format(x)
    df['Population_'] = df['Population'].apply(thousands_separator)
    return df['Population_']

answer_twelve()

#########################################
## Celcom

#Q1
def answer_one():
    merge = pd.merge(ScimEn1, energy, how='inner', left_on = 'Country', right_on = 'Country')
    merge_all = pd.merge(merge, GDP, how='inner', left_on = 'Country', right_on = 'Country')
    merge_all = merge_all.set_index('Country')
    return merge_all

answer_one()

#Q2
def answer_two():
    merge = pd.merge(ScimEn, energy, how='inner', left_on = 'Country', right_on = 'Country')
    merge_all = pd.merge(merge, GDP, how='inner', left_on = 'Country', right_on = 'Country')
    return len(merge_all) - len(merge_all.iloc[0:15])

answer_two()

#Q3
def answer_three():
    Top15 = answer_one()
    avgGDP = Top15[['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015']].mean(axis=1).sort_values(ascending=False)
    return avgGDP

answer_three()

#Q4
def answer_four():
    Top15 = answer_one()
    sixth = abs(Top15.iloc[3,10] - Top15.iloc[3,19])
    return sixth

answer_four()

#Q5
def answer_five():
    Top15 = answer_one()
    answer_five = Top15['Energy Supply per Capita'].mean()
    return answer_five

answer_five()

#Q6
def answer_six():
    Top15 = answer_one()
    max_country = Top15['% Renewable'].argmax()
    return (max_country, Top15['% Renewable'].max())

answer_six()

#Q7
def answer_seven():
    Top15 = answer_one()
    Top15['Ratio'] = Top15['Self-citations']/Top15['Citations']
    max_country = Top15['Ratio'].argmax()
    return (max_country, Top15['Ratio'].max())

answer_seven()

#Q8
def answer_eight():
    Top15 = answer_one()
    Top15['Population'] = Top15['Energy Supply']/Top15['Energy Supply per Capita']
    return Top15['Population'].sort_values(ascending=False).index[2]

answer_eight()

#Q9
def answer_nine():
    Top15 = answer_one()
    Top15['Pop'] = Top15['Energy Supply']/Top15['Energy Supply per Capita']
    Top15['CitePerPerson']=Top15['Citable documents']/Top15['Pop']
    correlation = Top15[['Energy Supply per Capita','CitePerPerson']].corr(method='pearson').values[0,1]
    return correlation

answer_nine()

#Q10
def answer_ten():
    Top15 = answer_one()
    mid = Top15['% Renewable'].median()
    Top15['HighRenew'] = Top15['% Renewable'] >= mid
    Top15['HighRenew'] = Top15['HighRenew'].apply(lambda x:1 if x else 0)
    Top15.sort_values(by='Rank', inplace=True)
    return new_merge['HighRenew']

answer_ten()

#Q11

merge3['Avg_GDP'] = answer_three()
merge3['Citations_Ratio']=answer_one()['Self-citations']/answer_one()['Citations']
merge3['Pop'] = merge3['Energy Supply']/merge3['Energy Supply per Capita']


def answer_eleven():
    merge3['Continent']= pd.Series({'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'})
    return pd.pivot_table(merge3, index=['Continent'], aggfunc=('size','sum','mean','std'))['Pop']

answer_eleven()
