# %% [markdown]
# # Exercise - Pandas II
#
# This exercise requires more individual learning then the last one did - you are encouraged to check out the [pandas documentation](http://pandas.pydata.org/pandas-docs/stable/) to find functions or methods you might not have used yet, or ask questions on [Stack Overflow](http://stackoverflow.com/) and tag them as pandas and python related. And of course, you are encouraged to interact with your coursemates and discuss about the questions and solutions.

# %% [markdown]
# ### Question 1
# Load the energy data from the file `Energy Indicators.xls`, which is a list of indicators of [energy supply and renewable electricity production](Energy%20Indicators.xls) from the [United Nations](http://unstats.un.org/unsd/environment/excel_file_tables/2013/Energy%20Indicators.xls) for the year 2013, and should be put into a DataFrame with the variable name of **energy**.
#
# Keep in mind that this is an Excel file, and not a comma separated values file. Also, make sure to exclude the footer and header information from the datafile. The first two columns are unneccessary, so you should get rid of them, and you should change the column labels so that the columns are:
#
# `['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']`
#
# Convert `Energy Supply` to gigajoules (there are 1,000,000 gigajoules in a petajoule). For all countries which have missing data (e.g. data with "...") make sure this is reflected as `np.NaN` values.
#
# Rename the following list of countries (for use in later questions):
#
# ```"Republic of Korea": "South Korea",
# "United States of America": "United States",
# "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
# "China, Hong Kong Special Administrative Region": "Hong Kong"```
#
# There are also several countries with numbers and/or parenthesis in their name. Be sure to remove these,
#
# e.g.
#
# `'Bolivia (Plurinational State of)'` should be `'Bolivia'`,
#
# `'Switzerland17'` should be `'Switzerland'`.
#
# <br>
#
# Next, load the GDP data from the file `world_bank.csv`, which is a csv containing countries' GDP from 1960 to 2015 from [World Bank](http://data.worldbank.org/indicator/NY.GDP.MKTP.CD). Call this DataFrame **GDP**.
#
# Make sure to skip the header, and rename the following list of countries:
#
# ```"Korea, Rep.": "South Korea",
# "Iran, Islamic Rep.": "Iran",
# "Hong Kong SAR, China": "Hong Kong"```
#
# <br>
#
# Finally, load the [Sciamgo Journal and Country Rank data for Energy Engineering and Power Technology](http://www.scimagojr.com/countryrank.php?category=2102) from the file `scimagojr-3.xlsx`, which ranks countries based on their journal contributions in the aforementioned area. Call this DataFrame **ScimEn**.
#
# Join the three datasets: GDP, Energy, and ScimEn into a new dataset (using the intersection of country names). Use only the last 10 years (2006-2015) of GDP data and only the top 15 countries by Scimagojr 'Rank' (Rank 1 through 15).
#
# The index of this DataFrame should be the name of the country, and the columns should be ['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations',
#        'Citations per document', 'H index', 'Energy Supply',
#        'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015'].
#
# *This function should return a DataFrame with 20 columns and 15 entries.*

# %%
# %pwd
# Out:
# 'C:\\Users\\Lau Chong Ee\\Desktop\\EDS4\\Content\\week04\\Exercise'

# %%
pd.read_excel?

# %%
import numpy as np

# %%
import pandas as pd

#energy

energy=pd.read_excel('../../data/week04/Energy Indicators.xls',na_values="...",
                     skiprows=17,skip_footer=38,parse_cols='C:F')
energy.columns=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']


energy.info()
energy['Energy Supply'] = 1000000*energy['Energy Supply']
energy['Country'] = energy['Country'].str.replace(r" \(.*\)","")
energy['Country'] = energy['Country'].str.replace(r"[0-9]+$","")
energy['Country']=energy['Country'].replace({"Republic of Korea": "South Korea","United States of America": "United States","United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
"China, Hong Kong Special Administrative Region": "Hong Kong"})


energy.tail(30)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 4 columns):
# Country                     227 non-null object
# Energy Supply               222 non-null float64
# Energy Supply per Capita    222 non-null float64
# % Renewable                 227 non-null float64
# dtypes: float64(3), object(1)
# memory usage: 7.2+ KB
#                                        Country  Energy Supply  \
# 197                                Switzerland   1.113000e+09
# 198                       Syrian Arab Republic   5.420000e+08
# 199                                 Tajikistan   1.060000e+08
# 200                                   Thailand   5.336000e+09
# 201  The former Yugoslav Republic of Macedonia   1.170000e+08
# 202                                Timor-Leste   7.000000e+06
# 203                                       Togo   1.340000e+08
# 204                                      Tonga   3.000000e+06
# ...

# %%
#GDP
GDP = pd.read_csv('../../data/week04/world_bank.csv', skiprows=4)
GDP['Country Name'] = GDP['Country Name'].replace({"Korea, Rep.": "South Korea","Iran, Islamic Rep.": "Iran",
"Hong Kong SAR, China": "Hong Kong"})
GDP.head()

GDP = GDP[['Country Name','2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']]
GDP.columns= ['Country','2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']
GDP.head(7)
# Out:
#                 Country          2006          2007          2008  \
# 0                 Aruba           NaN           NaN           NaN
# 1               Andorra  4.018196e+09  4.021331e+09  3.675728e+09
# 2           Afghanistan  1.030523e+10  1.172119e+10  1.214448e+10
# 3                Angola  5.581103e+10  6.842044e+10  7.787420e+10
# 4               Albania  9.771760e+09  1.034829e+10  1.112752e+10
# 5            Arab World  1.763824e+12  1.863481e+12  1.980983e+12
# 6  United Arab Emirates  2.789489e+11  2.878318e+11  2.970189e+11
#
#            2009          2010          2011          2012          2013  \
# 0           NaN  2.467704e+09           NaN           NaN           NaN
# 1  3.535389e+09  3.346317e+09  3.185605e+09  3.129538e+09  3.127550e+09
# 2  1.469733e+10  1.593680e+10  1.691113e+10  1.935220e+10  1.973134e+10
# 3  7.975320e+10  8.247091e+10  8.570262e+10  9.012096e+10  9.626143e+10
# 4  1.150029e+10  1.192695e+10  1.223109e+10  1.240477e+10  1.254247e+10
# ...

# %%
#Scimago
ScimEn = pd.read_excel('../../data/week04/scimagojr-3.xlsx')
ScimEn1 = ScimEn.iloc[0:15]
ScimEn1
ScimEn
# Out:
#      Rank                         Country  Documents  Citable documents  \
# 0       1                           China     127050             126767
# 1       2                   United States      96661              94747
# 2       3                           Japan      30504              30287
# 3       4                  United Kingdom      20944              20357
# 4       5              Russian Federation      18534              18301
# 5       6                          Canada      17899              17620
# 6       7                         Germany      17027              16831
# 7       8                           India      15005              14841
# 8       9                          France      13153              12973
# 9      10                     South Korea      11983              11923
# 10     11                           Italy      10964              10794
# 11     12                           Spain       9428               9330
# ...

# %%
def answer_one():
## Your answer here
answer_one()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
# def answer_one(energy, GDP, ScimEn1):
#     #set index to Country for each dataframe
#     energy = energy.reset_index().set_index('Country')
#     GDP = GDP.reset_index().set_index('Country')
#     ScimEn1 = ScimEn1.reset_index().set_index('Country')

#     #merge energy & ScimEn
#     new_df = pd.merge(ScimEn1, energy, how='inner', left_index=True, right_index=True)
#     #merge energy, SciemEn & GDP
#     final_df = pd.merge(new_df, GDP, how='inner', left_index=True, right_index=True)
#     final_df = final_df.reset_index().set_index('Country')
#     del final_df['index_x']
#     #final_df
#     return final_df

# answer_one(energy, GDP, ScimEn1)

def answer_one():
    df = pd.merge(ScimEn1, energy, how='inner',left_on='Country', right_on='Country')
    new_df = pd.merge(df,GDP,how='inner',left_on='Country',right_on='Country')
    new_df = new_df.set_index('Country')
    return new_df
   
answer_one()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %% [markdown]
# ### Question 2
# The previous question joined three datasets then reduced this to just the top 15 entries. When you joined the datasets, but before you reduced this to the top 15 items, how many entries did you lose?
#
# *This function should return a single number.*

# %%
# %%HTML
# <svg width="800" height="300">
#   <circle cx="150" cy="180" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="blue" />
#   <circle cx="200" cy="100" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="red" />
#   <circle cx="100" cy="100" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="green" />
#   <line x1="150" y1="125" x2="300" y2="150" stroke="black" stroke-width="2" fill="black" stroke-dasharray="5,3"/>
#   <text  x="300" y="165" font-family="Verdana" font-size="35">Everything but this!</text>
# </svg>
# Out:
# <svg width="800" height="300">
#   <circle cx="150" cy="180" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="blue" />
#   <circle cx="200" cy="100" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="red" />
#   <circle cx="100" cy="100" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="green" />
#   <line x1="150" y1="125" x2="300" y2="150" stroke="black" stroke-width="2" fill="black" stroke-dasharray="5,3"/>
#   <text  x="300" y="165" font-family="Verdana" font-size="35">Everything but this!</text>
# </svg>

# %%
# def answer_two(energy, GDP, ScimEn, ScimEn1):
#      #set index to Country for each dataframe
#     final_df = answer_one(energy, GDP, ScimEn1)
    
#     energy = energy.reset_index().set_index('Country')
#     GDP = GDP.reset_index().set_index('Country')
#     ScimEn = ScimEn.reset_index().set_index('Country')
#     #merge energy & ScimEn
#     new_df1 = pd.merge(ScimEn, energy, how='outer', left_index=True, right_index=True)
#     #merge energy, SciemEn & GDP
#     final_df1 = pd.merge(new_df1, GDP, how='outer', left_index=True, right_index=True)
#     final_df1 = final_df1.reset_index().set_index('Country')
#     del final_df1['index_x']
    
#     return len(final_df1 - final_df)
# answer_two(energy, GDP, ScimEn, ScimEn1)

#147

def answer_two():
    df = pd.merge(ScimEn,energy,how='inner',left_on='Country',right_on='Country')
    new_df1 = pd.merge(df,GDP,how='inner',left_on='Country',right_on='Country')
    new_df1 = new_df1.set_index('Country')
    print(new_df1.shape)

answer_two()
# Out:
# (162, 20)

# %% [markdown]
# <br>
#
# Answer the following questions in the context of only the top 15 countries by Scimagojr Rank (aka the DataFrame returned by `answer_one()`)

# %% [markdown]
# ### Question 3
# What is the average GDP over the last 10 years for each country? (exclude missing values from this calculation.)
#
# *This function should return a Series named `avgGDP` with 15 countries and their average GDP sorted in descending order.*

# %%
def answer_three():
    ## Your answer here

answer_three()
# Out:
# Country
# United States         1.536434e+13
# China                 6.348609e+12
# Japan                 5.542208e+12
# Germany               3.493025e+12
# France                2.681725e+12
# United Kingdom        2.487907e+12
# Brazil                2.189794e+12
# Italy                 2.120175e+12
# India                 1.769297e+12
# Canada                1.660647e+12
# Russian Federation    1.565459e+12
# Spain                 1.418078e+12
# Australia             1.164043e+12
# South Korea           1.106715e+12
# Iran                  4.441558e+11
# dtype: float64

# %%
# def answer_three(GDP, ScimEn1):
#     col_list = ['2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']    
#     new_df = answer_one(energy, GDP, ScimEn1)
#     avgGDP = pd.Series(new_df[col_list].mean(axis=1))
#     #avgGDP.sort_values(ascending=False).head(15)
#     return avgGDP.sort_values(ascending=False).head(15)

# answer_three(GDP, ScimEn1)

def answer_three():
    Top15 = answer_one()
    avgGDP = Top15[['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015']].mean(axis=1)
    avgGDP.sort_values(ascending=False, inplace=True)
    return avgGDP

answer_three()
# Out:
# Country
# United States         1.536434e+13
# China                 6.348609e+12
# Japan                 5.542208e+12
# Germany               3.493025e+12
# France                2.681725e+12
# United Kingdom        2.487907e+12
# Brazil                2.189794e+12
# Italy                 2.120175e+12
# India                 1.769297e+12
# Canada                1.660647e+12
# Russian Federation    1.565459e+12
# Spain                 1.418078e+12
# Australia             1.164043e+12
# South Korea           1.106715e+12
# Iran                  4.441558e+11
# dtype: float64

# %% [markdown]
# ### Question 4
# By how much had the GDP changed over the 10 year span for the country with the 6th largest average GDP?
#
# *This function should return a single number.*

# %%
def answer_four():
   ## Your answer here
   return ''

answer_four()
# Out:
# 246702696075.3999

# %%
# def answer_four(GDP):
#     avgGDP = answer_three(GDP, ScimEn1).reset_index()
#     country_6 = avgGDP.get_value(5, 'Country') #6th largest economic

#     GDP = GDP.reset_index().set_index('Country')
#     #GDP.loc[country_6]['2015'] - GDP.loc[country_6]['2006']
#     return GDP.loc[country_6]['2015'] - GDP.loc[country_6]['2006']

# answer_four(GDP)

def answer_four():
    Top15=answer_one()
    sixth = abs(Top15.iloc[3,10]-Top15.iloc[3,19])   
    return sixth

answer_four()

def answer_four_1():
    Top15=answer_one()
    sixth_country = answer_three().index[5]#.reset_index().get_value(5, 'Country')
    return abs(Top15.loc[sixth_country]['2015'] - Top15.loc[sixth_country]['2006'])

answer_four_1()
# Out:
# 246702696075.3999

# %% [markdown]
# ### Question 5
# What is the mean `Energy Supply per Capita`?
#
# *This function should return a single number.*

# %%
def answer_five():
    ## Your answer here

answer_five()
# Out:
# 157.6

# %%
# def answer_five():
#     # answer is 157.6??
#     return answer_one(energy, GDP, ScimEn1)['Energy Supply per Capita'].dropna().mean()

# answer_five()

def answer_five():
    Top15 = answer_one()
    ESPC = Top15['Energy Supply per Capita'].mean()
    return ESPC

answer_five()
# Out:
# 157.6

# %% [markdown]
# ### Question 6
# What country has the maximum % Renewable and what is the percentage?
#
# *This function should return a tuple with the name of the country and the percentage.*

# %%
def answer_six():
   ## Your answer here


answer_six()
# Out:
# ('Brazil', 69.648030000000006)

# %%
# def answer_six():
#    new_df = answer_one(energy, GDP, ScimEn1)   
#    country = new_df['% Renewable'].argmax()
#    return (country, new_df['% Renewable'].max())

# answer_six()

def answer_six():
    Top15 = answer_one()
    Renewable= Top15["% Renewable"].max()
    country = Top15['% Renewable'].argmax()
    return (country,Renewable)
       
answer_six()
# Out:
# ('Brazil', 69.648030000000006)

# %% [markdown]
# ### Question 7
# Create a new column that is the ratio of Self-Citations to Total Citations.
# What is the maximum value for this new column, and what country has the highest ratio?
#
# *This function should return a tuple with the name of the country and the ratio.*

# %%
# def answer_seven():
#     new_df = answer_one(energy, GDP, ScimEn1)
#     new_df['ratio'] = new_df['Self-citations']/new_df['Self-citations'].sum()
    
#     return (new_df['ratio'].argmax(), new_df['ratio'].max())

# answer_seven()

def answer_seven():
    Top15 = answer_one()
    Top15['Ratio'] = Top15['Self-citations']/Top15['Citations']
    MaxRatio= Top15['Ratio'].max()
    country = Top15['Ratio'].argmax()
    return (country, MaxRatio)

answer_seven()
# Out:
# ('China', 0.68931261793894216)

# %% [markdown]
# ### Question 8
#
# Create a column that estimates the population using Energy Supply and Energy Supply per capita.
# What is the third most populous country according to this estimate?
#
# *This function should return a single string value.*

# %%
def answer_eight():
## Your answer here
    return ''

answer_eight()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Energy Supply per capita'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-264-135d34ba582a> in <module>()
#       6
# ...

# %%
# def answer_eight():
#     new_df = answer_one(energy, GDP, ScimEn1)
#     new_df['Pop_Energy_Supply'] = new_df['Energy Supply']/new_df['Energy Supply per Capita']
#     #new_df.sort_values('Pop_Energy_Supply', ascending=False).reset_index().iloc[2]['Country']
#     return new_df.sort_values('Pop_Energy_Supply', ascending=False).reset_index().iloc[2]['Country']

# answer_eight()

def answer_eight():
    Top15 = answer_one()
    Top15['Pop'] = Top15['Energy Supply']/Top15['Energy Supply per Capita']
    SortedPop = Top15['Pop'].sort_values(ascending = False)
    return SortedPop.index[2]

answer_eight()
# Out:
# 'United States'

# %% [markdown]
# ### Question 9
# Create a column that estimates the number of citable documents per person.
# What is the correlation between the number of citable documents per capita and the energy supply per capita? Use the `.corr()` method, (Pearson's correlation).
#
# *This function should return a single number.*
#
# *(Optional: Use the built-in function `plot9()` to visualize the relationship between Energy Supply per Capita vs. Citable docs per Capita)*

# %%
def answer_nine():
## Your answer here

answer_nine()
# Out:
# 0.79400104354429435

# %%
# def answer_nine():
#     new_df = answer_one(energy, GDP, ScimEn1)
#     new_df['Pop_Energy_Supply'] = new_df['Energy Supply']/new_df['Energy Supply per Capita']
#     new_df['Citable docs per Capita'] = new_df['Citable documents']/new_df['Pop_Energy_Supply']
#     new_df['Corr_Citable_Energy'] = new_df['Citable docs per Capita'].corr(new_df['Energy Supply per Capita'], method='pearson')
#     #new_df['Corr_Citable_Energy'].iloc[0]
#     return new_df['Corr_Citable_Energy'].head(1)

# answer_nine()

def answer_nine():
    Top15 = answer_one()
    Top15['Pop'] = Top15['Energy Supply']/Top15['Energy Supply per Capita']
    Top15['CitePerPerson']=Top15['Citable documents']/Top15['Pop']
    correlation = Top15[['Energy Supply per Capita','CitePerPerson']].corr(method='pearson').values[0,1]
    #print(Top15[['Energy Supply per Capita','CitePerPerson']].corr(method='pearson'))
    return correlation

answer_nine()
# Out:
# 0.79400104354429435

# %%
def plot9():
    import matplotlib as plt
    # %matplotlib inline
    
    Top15 = answer_one()
    Top15['PopEst'] = Top15['Energy Supply'] / Top15['Energy Supply per Capita']
    Top15['Citable docs per Capita'] = Top15['Citable documents'] / Top15['PopEst']
    Top15.plot(x='Citable docs per Capita', y='Energy Supply per Capita', kind='scatter', xlim=[0, 0.0006])

# %%
plot9() # Be sure to comment out plot9() before submitting the assignment!    df = pd.merge(ScimEn1, energy, how='inner',left_on='Country', right_on='Country')

# %% [markdown]
# ### Question 10
# Create a new column with a 1 if the country's % Renewable value is at or above the median for all countries in the top 15, and a 0 if the country's % Renewable value is below the median.
#
# *This function should return a series named `HighRenew` whose index is the country name sorted in ascending order of rank.*

# %%
def answer_ten():
## Your answer here

answer_ten()
# Out:
#   File "<ipython-input-298-a68ae072118b>", line 4
#     answer_ten()
#              ^
# IndentationError: expected an indented block

# %%
# def answer_ten():
#     new_df = answer_one(energy, GDP, ScimEn1)
#     median = new_df['% Renewable'].median()
#     new_df['HighRenew'] = new_df['% Renewable'].apply(lambda x:1 if x > median else 0)
#     #new_df['HighRenew']
#     return new_df['HighRenew']
 
# answer_ten()

def answer_ten():
    Top15 = answer_one()
    renewable_median = answer_one()['% Renewable'].median()
    Top15['HighRenew'] = Top15['% Renewable'].apply(lambda x: 1 if x > renewable_median else 0)
    return Top15['HighRenew']
 
answer_ten()
# Out:
# Country
# China                 1
# United States         0
# Japan                 0
# United Kingdom        0
# Russian Federation    1
# Canada                1
# Germany               1
# India                 0
# France                0
# South Korea           0
# Italy                 1
# Spain                 1
# Iran                  0
# Australia             0
# Brazil                1
# Name: HighRenew, dtype: int64

# %% [markdown]
# ### Question 11
# Use the following dictionary to group the Countries by Continent, then create a dateframe that displays the sample size (the number of countries in each continent bin), and the sum, mean, and std deviation for the estimated population of each country.
#
# ```python
# ContinentDict  = {'China':'Asia',
#                   'United States':'North America',
#                   'Japan':'Asia',
#                   'United Kingdom':'Europe',
#                   'Russian Federation':'Europe',
#                   'Canada':'North America',
#                   'Germany':'Europe',
#                   'India':'Asia',
#                   'France':'Europe',
#                   'South Korea':'Asia',
#                   'Italy':'Europe',
#                   'Spain':'Europe',
#                   'Iran':'Asia',
#                   'Australia':'Australia',
#                   'Brazil':'South America'}
# ```
#
# *This function should return a DataFrame with index named Continent `['Asia', 'Australia', 'Europe', 'North America', 'South America']` and columns `['size', 'sum', 'mean', 'std']`*

# %%
Top15 = answer_one()
Top15
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
def answer_eleven():
    Top15 = answer_one()
    ContinentDict  = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}
    Top15['size'] = None
    Top15['Pop'] = Top15['Energy Supply']/Top15['Energy Supply per Capita']
    Top15['Continent'] = None
    for i in range(len(Top15)):
        Top15.iloc[i,20] = 1
        Top15.iloc[i,22]= ContinentDict[Top15.index[i]]
    #return Top15.set_index('Continent').groupby(level=0)['Pop'].agg({'size': np.size, 'sum': np.sum, 'mean': np.mean,'std': np.std})
    return pd.pivot_table(Top15, index=['Continent'], aggfunc=('size','sum','mean','std'))['Pop']

answer_eleven()
# Out:
#                        mean  size           std           sum
# Continent
# Asia           5.797333e+08     5  6.790979e+08  2.898666e+09
# Australia      2.331602e+07     1           NaN  2.331602e+07
# Europe         7.632161e+07     6  3.464767e+07  4.579297e+08
# North America  1.764276e+08     2  1.996696e+08  3.528552e+08
# South America  2.059153e+08     1           NaN  2.059153e+08

# %%
def answer_eleven():
    Top15 = answer_one()
    ContinentDict  = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}
    Top15['size'] = None
    Top15['Pop'] = Top15['Energy Supply']/Top15['Energy Supply per Capita']
    Top15['Continent'] = None
    for i in range(len(Top15)):
        Top15.iloc[i,20] = 1
        Top15.iloc[i,22]= ContinentDict[Top15.index[i]]
    return Top15.set_index('Continent').groupby(level=0)['Pop'].agg({'size': np.size, 'sum': np.sum, 'mean': np.mean,'std': np.std})
    #return pd.pivot_table(Top15, index=['Continent'], aggfunc=('size','sum','mean','std'))['Pop']

answer_eleven()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#                size           sum          mean           std
# Continent
# Asia            5.0  2.898666e+09  5.797333e+08  6.790979e+08
# Australia       1.0  2.331602e+07  2.331602e+07           NaN
# Europe          6.0  4.579297e+08  7.632161e+07  3.464767e+07
# North America   2.0  3.528552e+08  1.764276e+08  1.996696e+08
# South America   1.0  2.059153e+08  2.059153e+08           NaN

# %% [markdown]
# ### Question 12
# Convert the Population Estimate series to a string with thousands separator (using commas). Do not round the results.
#
# e.g. 317615384.61538464 -> 317,615,384.61538464
#
# *This function should return a Series `PopEst` whose index is the country name and whose values are the population estimate string.*

# %%
def answer_twelve():
## Your answer here

answer_twelve()
# Out:
# Country
# China                 1,367,645,161.2903225
# United States          317,615,384.61538464
# Japan                  127,409,395.97315437
# United Kingdom         63,870,967.741935484
# Russian Federation            143,500,000.0
# Canada                  35,239,864.86486486
# Germany                 80,369,696.96969697
# India                 1,276,730,769.2307692
# France                  63,837,349.39759036
# South Korea            49,805,429.864253394
# Italy                  59,908,256.880733944
# Spain                    46,443,396.2264151
# Iran                    77,075,630.25210084
# Australia              23,316,017.316017315
# Brazil                 205,915,254.23728815
# Name: PopEst, dtype: object

# %%
def answer_twelve():
    Top15 = answer_one()
    Top15['PopEst'] = Top15['Energy Supply'] / Top15['Energy Supply per Capita']
    return Top15['PopEst'].map(lambda x: "{:,}".format(x))

answer_twelve()
# Out:
# Country
# China                 1,367,645,161.2903225
# United States          317,615,384.61538464
# Japan                  127,409,395.97315437
# United Kingdom         63,870,967.741935484
# Russian Federation            143,500,000.0
# Canada                  35,239,864.86486486
# Germany                 80,369,696.96969697
# India                 1,276,730,769.2307692
# France                  63,837,349.39759036
# South Korea            49,805,429.864253394
# Italy                  59,908,256.880733944
# Spain                    46,443,396.2264151
# Iran                    77,075,630.25210084
# Australia              23,316,017.316017315
# Brazil                 205,915,254.23728815
# Name: PopEst, dtype: object

# %% [markdown]
# ### Optional
#
# Use the built in function `plot_optional()` to see an example visualization.

# %%
def plot_optional():
    import matplotlib as plt
    # %matplotlib inline
    Top15 = answer_one()
    ax = Top15.plot(x='Rank', y='% Renewable', kind='scatter', 
                    c=['#e41a1c','#377eb8','#e41a1c','#4daf4a','#4daf4a','#377eb8','#4daf4a','#e41a1c',
                       '#4daf4a','#e41a1c','#4daf4a','#4daf4a','#e41a1c','#dede00','#ff7f00'], 
                    xticks=range(1,16), s=6*Top15['2014']/10**10, alpha=.75, figsize=[16,6]);

    for i, txt in enumerate(Top15.index):
        ax.annotate(txt, [Top15['Rank'][i], Top15['% Renewable'][i]], ha='center')

    print("This is an example of a visualization that can be created to help understand the data. \
This is a bubble chart showing % Renewable vs. Rank. The size of the bubble corresponds to the countries' \
2014 GDP, and the color corresponds to the continent.")

# %%
plot_optional() # Be sure to comment out plot_optional() before submitting the assignment!
# Out:
# This is an example of a visualization that can be created to help understand the data. This is a bubble chart showing % Renewable vs. Rank. The size of the bubble corresponds to the countries' 2014 GDP, and the color corresponds to the continent.
